# %%
import pandas as pd
import plotly.express as px

tabela = pd.read_csv('Heart_Disease_Prediction.csv')
display(tabela.head())
print(tabela.info())

grafico = px.histogram(tabela, x='Heart Disease', color='Heart Disease', barmode='group')
grafico.show()
# Out:
#    Age  Sex  Chest pain type   BP  Cholesterol  FBS over 120  EKG results  \
# 0   70    1                4  130          322             0            2
# 1   67    0                3  115          564             0            2
# 2   57    1                2  124          261             0            0
# 3   64    1                4  128          263             0            0
# 4   74    0                2  120          269             0            2
#
#    Max HR  Exercise angina  ST depression  Slope of ST  \
# 0     109                0            2.4            2
# 1     160                0            1.6            2
# 2     141                0            0.3            1
# 3     105                1            0.2            2
# 4     121                1            0.2            1
#
#    Number of vessels fluro  Thallium Heart Disease
# 0                        3         3      Presence
# 1                        0         7       Absence
# ...

# %%
x = tabela.drop('Heart Disease', axis=1)
y = tabela['Heart Disease']

from sklearn.model_selection import train_test_split
x_treino, x_teste, y_treino, y_teste = train_test_split(x, y, test_size=0.3)

from sklearn.ensemble import RandomForestClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import GradientBoostingClassifier

modelo_rf = RandomForestClassifier()
modelo_lr = LogisticRegression()
modelo_dt = DecisionTreeClassifier()
modelo_gd = GradientBoostingClassifier()

modelo_rf.fit(x_treino, y_treino)
modelo_lr.fit(x_treino, y_treino)
modelo_dt.fit(x_treino, y_treino)
modelo_gd.fit(x_treino, y_treino)
# Out:
# c:\Users\supra\Desktop\DATA_SCIENCE_PROJECTS\ML_Doenças_Cardiacas\.venv\Lib\site-packages\sklearn\linear_model\_logistic.py:406: ConvergenceWarning:
#
# lbfgs failed to converge after 100 iteration(s) (status=1):
# STOP: TOTAL NO. OF ITERATIONS REACHED LIMIT
#
# Increase the number of iterations to improve the convergence (max_iter=100).
# You might also want to scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
# GradientBoostingClassifier()

# %%
from sklearn.metrics import recall_score
from sklearn.metrics import confusion_matrix

previsao_rf = modelo_rf.predict(x_teste)
previsao_lr = modelo_lr.predict(x_teste)
previsao_dt = modelo_dt.predict(x_teste)
previsao_gd = modelo_gd.predict(x_teste)

print('Random Forest:', recall_score(y_teste, previsao_rf, pos_label='Presence'))
print('Logistic Regression:', recall_score(y_teste, previsao_lr, pos_label='Presence'))
print('Decision Tree:', recall_score(y_teste, previsao_dt, pos_label='Presence'))
print('Gradient Boosting:', recall_score(y_teste, previsao_gd, pos_label='Presence'))
print('\n')

print('Random Forest:\n', confusion_matrix(y_teste, previsao_rf))
print('Logistic Regression:\n', confusion_matrix(y_teste, previsao_lr))
print('Decision Tree:\n', confusion_matrix(y_teste, previsao_dt))
print('Gradient Boosting:\n', confusion_matrix(y_teste, previsao_gd))
# Out:
# Random Forest: 0.7948717948717948
# Logistic Regression: 0.7948717948717948
# Decision Tree: 0.5897435897435898
# Gradient Boosting: 0.7948717948717948
#
#
# Random Forest:
#  [[39  3]
#  [ 8 31]]
# Logistic Regression:
#  [[37  5]
#  [ 8 31]]
# Decision Tree:
#  [[33  9]
#  [16 23]]
# Gradient Boosting:
#  [[33  9]
#  [ 8 31]]

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import make_scorer
scaler = StandardScaler()
x_treino = scaler.fit_transform(x_treino)
x_teste = scaler.transform(x_teste)

param_grid = {
    'C': [0.01, 0.1, 1, 10, 100],
    'penalty': ['l1', 'l2'],
    'solver': ['liblinear', 'saga'],
    'max_iter': [200, 500, 1000]
}
scorer = make_scorer(recall_score, pos_label='Presence')

grid_search = GridSearchCV(
    estimator=LogisticRegression(),
    param_grid=param_grid,
    cv=5,
    scoring=scorer,   # usando o scorer personalizado
    n_jobs=-1,
    verbose=1
)

grid_search.fit(x_treino, y_treino)
# Out:
# Fitting 5 folds for each of 60 candidates, totalling 300 fits
# c:\Users\supra\Desktop\DATA_SCIENCE_PROJECTS\ML_Doenças_Cardiacas\.venv\Lib\site-packages\sklearn\linear_model\_logistic.py:1135: FutureWarning:
#
# 'penalty' was deprecated in version 1.8 and will be removed in 1.10. To avoid this warning, leave 'penalty' set to its default value and use 'l1_ratio' or 'C' instead. Use l1_ratio=0 instead of penalty='l2', l1_ratio=1 instead of penalty='l1', and C=np.inf instead of penalty=None.
#
# c:\Users\supra\Desktop\DATA_SCIENCE_PROJECTS\ML_Doenças_Cardiacas\.venv\Lib\site-packages\sklearn\linear_model\_logistic.py:1160: UserWarning:
#
# Inconsistent values: penalty=l1 with l1_ratio=0.0. penalty is deprecated. Please use l1_ratio only.
# GridSearchCV(cv=5, estimator=LogisticRegression(), n_jobs=-1,
#              param_grid={'C': [0.01, 0.1, 1, 10, 100],
#                          'max_iter': [200, 500, 1000], 'penalty': ['l1', 'l2'],
# ...

# %%
print("Melhores hiperparâmetros:", grid_search.best_params_)
print("Melhor recall (cross-val):", round(grid_search.best_score_, 4))
# Out:
# Melhores hiperparâmetros: {'C': 0.1, 'max_iter': 200, 'penalty': 'l1', 'solver': 'liblinear'}
# Melhor recall (cross-val): 0.814

# %%
melhor_modelo = grid_search.best_estimator_
previsao_otimizada = melhor_modelo.predict(x_teste)

# %%
print("\nRecall no teste:", round(recall_score(y_teste, previsao_otimizada, pos_label='Presence'), 4))
print("Confusion Matrix:\n", confusion_matrix(y_teste, previsao_otimizada))
# Out:
# Recall no teste: 0.8462
# Confusion Matrix:
#  [[35  7]
#  [ 6 33]]

# %%
import joblib

joblib.dump(melhor_modelo, 'modelo_heart_disease.pkl')
joblib.dump(scaler, 'scaler.pkl')
# Out:
# ['scaler.pkl']
